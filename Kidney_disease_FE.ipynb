# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('kidney_disease.csv')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    397 non-null    int64
#  1   age                   397 non-null    int64
#  2   bp                    397 non-null    int64
#  3   sg                    397 non-null    float64
#  4   albumin               397 non-null    int64
#  5   sugar                 397 non-null    int64
#  6   rbc                   397 non-null    object
#  7   pus_cell              397 non-null    object
#  8   pcclumps              397 non-null    object
#  9   bacteria              397 non-null    object
#  10  blood_glucose_random  397 non-null    int64
#  11  blood_urea            397 non-null    float64
#  12  serum_c               397 non-null    float64
#  13  sodium                397 non-null    int64
#  14  potassium             397 non-null    float64
# ...

# %%
df.head()
# Out:
#    id  age  bp     sg  albumin  sugar     rbc  pus_cell    pcclumps  \
# 0   1   48  80  1.020        1      0  normal    normal  notpresent
# 1   2    7  50  1.020        4      0  normal    normal  notpresent
# 2   3   62  80  1.010        2      3  normal    normal  notpresent
# 3   4   48  70  1.005        4      0  normal  abnormal     present
# 4   5   51  80  1.010        2      0  normal    normal  notpresent
#
#      bacteria  ...  pcv  wbc_count  rbc_count  hyptension  diabetes-mellitus  \
# 0  notpresent  ...   44       7800        5.2         yes                yes
# 1  notpresent  ...   38       6000        4.8          no                 no
# 2  notpresent  ...   31       7500        4.8          no                yes
# 3  notpresent  ...   32       6700        3.9         yes                 no
# 4  notpresent  ...   35       7300        4.6          no                 no
#
#    cor_artery_disease  appetite   pe  anemia class
# ...

# %%
def normal(i):
    if i=='normal':
        return 1
    elif i=='abnormal':
        return 0

# %%
df['rbc'] = df['rbc'].apply(normal)

# %%
df['rbc'].value_counts()
# Out:
# 1    350
# 0     47
# Name: rbc, dtype: int64

# %%
df['pus_cell']=df['pus_cell'].apply(normal)

# %%
def present(i):
    if i=='present':
        return 1
    elif i=='notpresent':
        return 0

# %%
df['pcclumps']=df['pcclumps'].apply(present)

# %%
df['bacteria']=df['bacteria'].apply(present)

# %%
def yes_no(i):
    if i=='yes':
        return 1
    elif i=='no':
        return 0

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'albumin', 'sugar', 'rbc', 'pus_cell',
#        'pcclumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_c',
#        'sodium', 'potassium', 'hemoglobin', 'pcv', 'wbc_count', 'rbc_count',
#        'hyptension', 'diabetes-mellitus', 'cor_artery_disease', 'appetite',
#        'pe', 'anemia', 'class'],
#       dtype='object')

# %%
df['hyptension']=df['hyptension'].apply(yes_no)

# %%
df['diabetes-mellitus']=df['diabetes-mellitus'].apply(yes_no)

# %%
df['cor_artery_disease']=df['cor_artery_disease'].apply(yes_no)

# %%
df['pe']=df['pe'].apply(yes_no)

# %%
df['anemia']=df['anemia'].apply(yes_no)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    397 non-null    int64
#  1   age                   397 non-null    int64
#  2   bp                    397 non-null    int64
#  3   sg                    397 non-null    float64
#  4   albumin               397 non-null    int64
#  5   sugar                 397 non-null    int64
#  6   rbc                   397 non-null    int64
#  7   pus_cell              397 non-null    int64
#  8   pcclumps              397 non-null    int64
#  9   bacteria              397 non-null    int64
#  10  blood_glucose_random  397 non-null    int64
#  11  blood_urea            397 non-null    float64
#  12  serum_c               397 non-null    float64
#  13  sodium                397 non-null    int64
#  14  potassium             397 non-null    float64
# ...

# %%
def appetite(i):
    if i=='good':
        return 1
    elif i=='poor':
        return 0

# %%
df['appetite'].value_counts()
# Out:
# good    315
# poor     82
# Name: appetite, dtype: int64

# %%
df['appetite']=df['appetite'].apply(appetite)

# %%
df
# Out:
#       id  age  bp     sg  albumin  sugar  rbc  pus_cell  pcclumps  bacteria  \
# 0      1   48  80  1.020        1      0    1         1         0         0
# 1      2    7  50  1.020        4      0    1         1         0         0
# 2      3   62  80  1.010        2      3    1         1         0         0
# 3      4   48  70  1.005        4      0    1         0         1         0
# 4      5   51  80  1.010        2      0    1         1         0         0
# ..   ...  ...  ..    ...      ...    ...  ...       ...       ...       ...
# 392  393   55  80  1.020        0      0    1         1         0         0
# 393  394   42  70  1.025        0      0    1         1         0         0
# 394  395   12  80  1.020        0      0    1         1         0         0
# 395  396   17  60  1.025        0      0    1         1         0         0
# 396  397   58  80  1.025        0      0    1         1         0         0
#
# ...

# %%
def class_fun(i):
    if i == 'ckd':
        return 1
    elif i == 'notckd':
        return 0

# %%
df['class'] = df['class'].apply(class_fun)

# %%
df
# Out:
#       id  age  bp     sg  albumin  sugar  rbc  pus_cell  pcclumps  bacteria  \
# 0      1   48  80  1.020        1      0    1         1         0         0
# 1      2    7  50  1.020        4      0    1         1         0         0
# 2      3   62  80  1.010        2      3    1         1         0         0
# 3      4   48  70  1.005        4      0    1         0         1         0
# 4      5   51  80  1.010        2      0    1         1         0         0
# ..   ...  ...  ..    ...      ...    ...  ...       ...       ...       ...
# 392  393   55  80  1.020        0      0    1         1         0         0
# 393  394   42  70  1.025        0      0    1         1         0         0
# 394  395   12  80  1.020        0      0    1         1         0         0
# 395  396   17  60  1.025        0      0    1         1         0         0
# 396  397   58  80  1.025        0      0    1         1         0         0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    397 non-null    int64
#  1   age                   397 non-null    int64
#  2   bp                    397 non-null    int64
#  3   sg                    397 non-null    float64
#  4   albumin               397 non-null    int64
#  5   sugar                 397 non-null    int64
#  6   rbc                   397 non-null    int64
#  7   pus_cell              397 non-null    int64
#  8   pcclumps              397 non-null    int64
#  9   bacteria              397 non-null    int64
#  10  blood_glucose_random  397 non-null    int64
#  11  blood_urea            397 non-null    float64
#  12  serum_c               397 non-null    float64
#  13  sodium                397 non-null    int64
#  14  potassium             397 non-null    float64
# ...

# %%
df.to_csv('Kidney_disease_FE.csv')
